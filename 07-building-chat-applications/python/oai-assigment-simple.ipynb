# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("OPENAI_API_KEY","").strip()
assert API_KEY, "ERROR: OpenAI Key is missing"
client = OpenAI(
    api_key=API_KEY
    )

model = "gpt-3.5-turbo"

# %%
# Create your first prompt
text_prompt = " My foot hurts, what can be wrong?"

response = client.chat.completions.create(
  model=model,
  messages = [
      {"role":"system", "content":"I'm a doctor, specialist on surgery"},
      {"role":"user","content":text_prompt},])

response.choices[0].message.content
# Out:
# "There are many potential causes for foot pain, ranging from simple issues like muscle strains and overuse to more serious conditions like fractures, tendonitis, or arthritis. It's important to consider your symptoms and any possible triggers that may have caused your foot pain. \n\nI would recommend seeking medical attention from a doctor or specialist, like a podiatrist or orthopedic surgeon, who can perform a physical examination, take a medical history, and possibly order imaging studies like x-rays or MRIs to determine the underlying cause of your foot pain. Treatment options will vary depending on the diagnosis, but may include rest, physical therapy, medication, or in some cases, surgery."
